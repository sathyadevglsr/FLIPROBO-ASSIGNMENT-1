# %% [markdown]
# ASSIGNMENT 1

# %% [markdown]
# 1) Write a python program to display all the header tags from wikipedia.org

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_1 = requests.get('https://en.wikipedia.org/wiki/Main_Page')
url_1
Soup = BeautifulSoup(url_1.content)
Header = []
for i in Soup.find_all('span',class_="mw-headline"):
    Header.append(i.text)    
Header
# Out:
# ['Welcome to Wikipedia',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %% [markdown]
# 2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
# and make data frame.

# %%
from bs4 import BeautifulSoup
import requests

import re

# %%
# Downloading imdb top 250 movie's data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# %%
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]

# %%
ratings = [b.attrs.get('data-value')
		for b in soup.select('td.posterColumn span[name=ir]')]

votes = [b.attrs.get('data-value')
		for b in soup.select('td.ratingColumn strong')]

list = []

# %%
# create a empty list for storing
# movie information
list = []

# %%
# Iterating over movies to extract
# each movie's details
for index in range(0, 101):
	
	# Separating movie into: 'place',
	# 'title', 'year'
	movie_string = movies[index].get_text()
	movie = (' '.join(movie_string.split()).replace('.', ''))
	movie_title = movie[len(str(index))+1:-7]
	year = re.search('\((.*?)\)', movie_string).group(1)
	place = movie[:len(str(index))-(len(movie))]
	data = {"movie_title": movie_title,
			"year": year,
			"place": place,
			"star_cast": crew[index],
			"rating": ratings[index],
			"vote": votes[index],
			"link": links[index]}
	list.append(data)
print('\033[1m'+'IMDB’s Top rated 100 movies of all time'+'\033[0m')
# Out:
# IMDB’s Top rated 100 movies of all time

# %%
# printing movie details with its rating.
for movie in list:
	print(movie['place'], '-', movie['movie_title'], '('+movie['year'] +
		') -', 'Starring:', movie['star_cast'], movie['rating'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman 9.235279330576516
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino 9.156088433799635
# 3 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger 8.989325611260593
# 4 - The Godfather Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro 8.984048053260283
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb 8.95085756154891
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes 8.938129898972933
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen 8.92871797776657
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman 8.848391972189292
# ...

# %% [markdown]
# 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of
# release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import re


# Downloading imdb top 250 movie's data
url = 'https://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]

ratings = [b.attrs.get('data-value')
		for b in soup.select('td.posterColumn span[name=ir]')]

votes = [b.attrs.get('data-value')
		for b in soup.select('td.ratingColumn strong')]

list = []

# create a empty list for storing
# movie information
list = []

# Iterating over movies to extract
# each movie's details
for index in range(0, 101):
	
	# Separating movie into: 'place',
	# 'title', 'year'
	movie_string = movies[index].get_text()
	movie = (' '.join(movie_string.split()).replace('.', ''))
	movie_title = movie[len(str(index))+1:-7]
	year = re.search('\((.*?)\)', movie_string).group(1)
	place = movie[:len(str(index))-(len(movie))]
	data = {"movie_title": movie_title,
			"year": year,
			"place": place,
			"star_cast": crew[index],
			"rating": ratings[index],
			"vote": votes[index],
			"link": links[index]}
	list.append(data)

print('\033[1m'+'IMDB’s Top rated 100 Indian movies'+'\033[0m')
# printing movie details with its rating.
for movie in list:
	print(movie['place'], '-', movie['movie_title'], '('+movie['year'] +
		') -', 'Starring:', movie['star_cast'], movie['rating'])
# Out:
# IMDB’s Top rated 100 Indian movies
# 1 - Ramayana: The Legend of Prince Rama (1993) - Starring: Ram Mohan (dir.), Bryan Cranston, Arun Govil 8.53823355924351
# 2 - Rocketry: The Nambi Effect (2022) - Starring: Madhavan (dir.), Madhavan, Simran 8.435334050620336
# 3 - 777 Charlie (2022) - Starring: Kiranraj K (dir.), Rakshit Shetty, Charlie 8.39789067956493
# 4 - Golmaal (1979) - Starring: Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami 8.39767796557642
# 5 - Nayakan (1987) - Starring: Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan 8.393519345784913
# 6 - Anbe Sivam (2003) - Starring: Sundar C. (dir.), Kamal Haasan, Madhavan 8.389004676045142
# 7 - Jai Bhim (2021) - Starring: T.J. Gnanavel (dir.), Suriya, Lijo Mol Jose 8.377801735642283
# 8 - Pariyerum Perumal (2018) - Starring: Mari Selvaraj (dir.), Kathir, Anandhi 8.358226808200529
# 9 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan 8.353090429713037
# ...

# %% [markdown]
# 4) Write s python program to display list of respected former presidents of India(i.e. Name , Term of office)
# from https://presidentofindia.nic.in/former-presidents.htm

# %%
url_4=requests.get('https://presidentofindia.nic.in/former-presidents.htm')
url_4
soup=BeautifulSoup(url_4.content)
Presidents = []
for i in soup.find_all('div',class_="presidentListing"):
    Presidents.append(i.get_text().split("\n")[1])
Presidents
# Out:
# ['Shri Ram Nath Kovind (birth - 1945)',
#  'Shri Pranab Mukherjee (1935-2020)',
#  'Smt Pratibha Devisingh Patil (birth - 1934)',
#  'DR. A.P.J. Abdul Kalam (1931-2015)',
#  'Shri K. R. Narayanan (1920 - 2005)',
#  'Dr Shankar Dayal Sharma (1918-1999)',
#  'Shri R Venkataraman (1910-2009)',
#  'Giani Zail Singh (1916-1994)',
#  'Shri Neelam Sanjiva Reddy (1913-1996)',
#  'Dr. Fakhruddin Ali Ahmed (1905-1977)',
#  'Shri Varahagiri Venkata Giri (1894-1980)',
#  'Dr. Zakir Husain (1897-1969)',
#  'Dr. Sarvepalli Radhakrishnan (1888-1975)',
#  'Dr. Rajendra Prasad (1884-1963) ']

# %% [markdown]
# 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

# %%
url = 'https://www.icc-cricket.com/rankings/mens/team-rankings/odi'

response = requests.get(url)
print(response.status_code, '--->',url)
print('\n')
soup= BeautifulSoup(response.content, 'lxml')
# Out:
# 200 ---> https://www.icc-cricket.com/rankings/mens/team-rankings/odi

# %%
Team=[]
Matches=[]
Points=[]
Rating=[]
Country = soup.find_all('span',class_="u-hide-phablet")
for i in Country:
    Team.append(i.get_text().replace("\n",""))
    Team=Team[0:10]

match=soup.find_all('td',class_='rankings-block__banner--matches')
matchs=soup.find_all('td',class_='table-body__cell u-center-text')
mtc = match + matchs

for i in mtc:
    Matches.append(i.text)
    Matches=Matches[0:10]
    
pt=soup.find_all('td',class_="rankings-block__banner--points")

pts= soup.find_all('td',class_ ="table-body__cell u-center-text")
Point= pt + pts
for i in Point:
    Points.append(i.get_text().replace("\n",""))
    Points=Points[0:10]
rating = soup.find_all('td',class_="table-body__cell u-text-right rating")
for i in rating:
    Rating.append(i.get_text().replace("\n",""))
    Rating=Rating[0:10]
    
ODI=pd.DataFrame({})
ODI['Country']=Team
ODI['Matches']=Matches
ODI['Rating']=Rating
ODI['Points']=Points
print('\033[1m'+'ICC MENS ODI RANKING'+'\033[0m') # Print Title in bold case
ODI
# Out:
# ICC MENS ODI RANKING
#         Country Matches Rating Points
# 0   New Zealand      23    113  2,670
# 1       England      30    112     30
# 2     Australia   3,400    110  3,400
# 3         India      32    107     32
# 4      Pakistan   3,572    100  3,572
# 5  South Africa      35     92     35
# 6    Bangladesh   3,866     89  3,866
# 7     Sri Lanka      22     73     22
# 8   Afghanistan   2,354     71  2,354
# 9   West Indies      24     53     24

# %%
# ICC Bating Ranking

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'
}

response = requests.get(url)
print(response.status_code, '--->',url)
print('\n\n')
soup= BeautifulSoup(response.content, 'lxml')
Position =[]
Player =[]
Country =[]
Rating =[]

# Extracting Data of Top Player from Banner
block_1= soup.find('tr', attrs={'class':'rankings-block__banner'}) # contains Top Player ranking detail

Position.append(block_1.find('td',class_='rankings-block__position').text)# Ranking Position
Player.append(block_1.find('div', class_="rankings-block__banner--name-large").text) # Extract Player Name
Country.append(block_1.find('span', class_='rankings-block__banner--nation').text)# Extract Country Name
Rating.append(block_1.find('div', class_="rankings-block__banner--rating").text) # Extract Rating

# Extracting other Player Ranking
table_rows =soup.find_all('tr', attrs={'class':'table-body'})

for row in table_rows[:10]:
    Position.append(row.find('td', class_='table-body__cell table-body__cell--position u-text-right').text.replace('\n',''))
    Player.append(row.find('a').text)
    Country.append(row.find('span', class_='table-body__logo-text').text)
    Rating.append(row.find('td', class_='table-body__cell rating').text)
    
# Storing data in Dataframe
ODI_Batmans=pd.DataFrame({'Ranking':Position,'Player_Name':Player, 'Team':Country, 'Rating':Rating})

print('\033[1m'+'ICC ODI MENS BATTING RANKING'+'\033[0m') # Print Title in bold case
ODI_Batmans
# Out:
# 200 ---> https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting
#
#
#
# ICC ODI MENS BATTING RANKING
#                                               Ranking            Player_Name  \
# 0   \n\n\n                            1\n         ...             Babar Azam
# 1                                       2         ...            Imam-ul-Haq
# 2                                       3         ...  Rassie van der Dussen
# 3                                       4         ...        Quinton de Kock
# 4                                       5         ...           David Warner
# 5                                       6         ...            Steve Smith
# 6                                       7         ...         Jonny Bairstow
# 7                                       8         ...            Virat Kohli
# 8                                       9         ...           Rohit Sharma
# 9                                       10        ...        Kane Williamson
# ...

# %%
# ICC ODI Mens Bowling Ranking

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'
}

response = requests.get(url)
print(response.status_code, '--->',url)
print('\n\n')
soup= BeautifulSoup(response.content, 'lxml')
Position =[]
Player =[]
Country =[]
Rating =[]

# Extracting Data of Top Player from Banner
block_1= soup.find('tr', attrs={'class':'rankings-block__banner'}) # contains Top Player ranking detail

Position.append(block_1.find('td',class_='rankings-block__position').text)# Ranking Position
Player.append(block_1.find('div', class_="rankings-block__banner--name-large").text) # Extract Player Name
Country.append(block_1.find('span', class_='rankings-block__banner--nation').text)# Extract Country Name
Rating.append(block_1.find('div', class_="rankings-block__banner--rating").text) # Extract Rating

# Extracting other Player Ranking
table_rows =soup.find_all('tr', attrs={'class':'table-body'})

for row in table_rows[:10]:
    Position.append(row.find('td', class_='table-body__cell table-body__cell--position u-text-right').text.replace('\n',''))
    Player.append(row.find('a').text)
    Country.append(row.find('span', class_='table-body__logo-text').text)
    Rating.append(row.find('td', class_='table-body__cell rating').text)
    
# Storing data in Dataframe
ODI_Bowling=pd.DataFrame({'Ranking':Position,'Player_Name':Player, 'Team':Country, 'Rating':Rating})

print('\033[1m'+'ICC ODI MENS BOWLING RANKING'+'\033[0m') # Print Title in bold case
ODI_Bowling
# Out:
# 200 ---> https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling
#
#
#
# ICC ODI MENS BOWLING RANKING
#                                               Ranking        Player_Name Team  \
# 0   \n\n\n                            1\n         ...        Trent Boult
# 1                                       2         ...     Josh Hazlewood  AUS
# 2                                       3         ...     Mitchell Starc  AUS
# 3                                       4         ...     Shaheen Afridi  PAK
# 4                                       5         ...         Matt Henry   NZ
# 5                                       6         ...         Adam Zampa  AUS
# 6                                       7         ...       Mehedi Hasan  BAN
# 7                                       8         ...   Mujeeb Ur Rahman  AFG
# 8                                       9         ...  Mustafizur Rahman  BAN
# 9                                       10        ...        Rashid Khan  AFG
# ...

# %% [markdown]
# 6) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
page6 =requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
women=BeautifulSoup(page6.content,"html.parser")

# %%
teams =[]
for i in women.find_all("span",class_="u-hide-phablet"):
    teams.append(i.get_text())

# %%
matches=[]
matches.append((women.find("td",class_="rankings-block__banner--matches")).text)
x=1
for i in women.find_all("td",class_="table-body__cell u-center-text"):
    if x%2==1:
        matches.append(i.text)
    x=x+1

# %%
points=[]
points.append((women.find("td",class_="rankings-block__banner--points")).text)
x-=1

for i in women.find_all("td",class_="table-body__cell u-center-text"):
    if x%2==0:
        points.append(i.text)
    x=x+1


ratings=[]

for i in women.find_all("td",class_="rankings-block__banner--rating u-text-right"):
    ratings.append(i.get_text().replace("\n","").replace(" ",""))
    
for i in women.find_all("td",class_="table-body__cell u-text-right rating"):
    ratings.append(i.get_text())

#Making DataFrame

df= pd.DataFrame({'Teams':teams,'Matches':matches,'Points':points,'Ratings':ratings})
dfw= df.head(10)
dfw
# Out:
#           Teams Matches Points Ratings
# 0     Australia      18  3,061     170
# 1  South Africa      26     26     119
# 2       England      25     25     116
# 3         India      27     27     104
# 4   New Zealand      24     24     101
# 5   West Indies      24     24      97
# 6    Bangladesh      12     12      78
# 7      Thailand       8      8      72
# 8      Pakistan      24     24      63
# 9     Sri Lanka       8      8      44

# %%
page7 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")
batsw= BeautifulSoup(page7.content,"html.parser")


name=[]
name.append((batsw.find("div", "rankings-block__banner--name")).text)
for i in batsw.find_all("td","table-body__cell name"):
    name.append(i.get_text().replace("\n",""))

wteam=[]
wteam.append((batsw.find("div", "rankings-block__banner--nationality")).text.split("\n")[2])

for i in batsw.find_all("span","table-body__logo-text"):
  
        wteam.append(i.text)
wrating=[]
wrating.append((batsw.find("div", "rankings-block__banner--rating")).text)
for i in batsw.find_all("td","table-body__cell u-text-right rating"):
    wrating.append(i.get_text())

df=pd.DataFrame({"Player":name,"Team":wteam,"Rating":wrating})
df[0:10]
# Out:
#                 Player Team Rating
# 0         Alyssa Healy  AUS    785
# 1          Beth Mooney  AUS    749
# 2      Laura Wolvaardt   SA    732
# 3       Natalie Sciver  ENG    725
# 4     Harmanpreet Kaur  IND    716
# 5      Smriti Mandhana  IND    714
# 6          Meg Lanning  AUS    710
# 7       Rachael Haynes  AUS    701
# 8    Amy Satterthwaite   NZ    661
# 9  Chamari Athapaththu   SL    655

# %%
allrounders_11=df.iloc[19:29,: ].reset_index(drop = True)
allrounders_11
# Out:
#              Player Team Rating
# 0      Ellyse Perry  AUS    374
# 1    Natalie Sciver  ENG    357
# 2       Amelia Kerr   NZ    356
# 3    Marizanne Kapp   SA    349
# 4     Deepti Sharma  IND    322
# 5  Ashleigh Gardner  AUS    270
# 6     Jess Jonassen  AUS    246
# 7    Jhulan Goswami  IND    214
# 8   Katherine Brunt  ENG    207

# %% [markdown]
# 7) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :
# i) Headline
# ii) Time
# iii) News Link

# %%
page8 = requests.get('https://www.cnbc.com/world/?region=world')
news = BeautifulSoup(page8.content,'html.parser')

# %%
title=[]
for i in news.find_all("a",class_="LatestNews-headline"):
    title.append(i.get_text())
    
time=[]
for i in news.find_all("time",class_="LatestNews-timestamp"):
    time.append(i.get_text())
    
url=[]
for links in news.find_all("a",class_="LatestNews-headline"):
    links=links.get('href')

# %%
df= pd.DataFrame({'Headline':title,'Time':time,'News link':links})
df
# Out:
#                                              Headline          Time  \
# 0   Parking lots are becoming as important as cars...   2 Hours Ago
# 1   Amazon's cloud unit faces cost-sensitive custo...   4 Hours Ago
# 2   Don’t overlook this health warning on your dec...   4 Hours Ago
# 3   How electric air taxis could shake up the airl...   4 Hours Ago
# 4   I raised 2 successful CEOs and a doctor. Here'...   4 Hours Ago
# 5   Delta pilots would get more than 30% in pay ra...   4 Hours Ago
# 6   Men participate less in 401(k) plans than wome...   5 Hours Ago
# 7   The best U.S. states to raise a family if you ...   5 Hours Ago
# 8   Susan Cain: This Bob Dylan-inspired phrase can...   5 Hours Ago
# 9   The difference between this comeback and the m...   5 Hours Ago
# 10  Goldman says buy these five stocks for the lon...   5 Hours Ago
# 11  Celsius users with crypto collateral stuck tur...   6 Hours Ago
# 12  Cramer's lightning round: Let Extreme Networks...  18 Hours Ago
# ...

# %% [markdown]
# 8) Write a python program to scrape the details of most downloaded articles from AI in last 90 days.
# https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape below mentioned details :
# i) Paper Title
# ii) Authors
# iii) Published Date
# iv) Paper URL

# %%
page9 = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
article = BeautifulSoup(page9.content,'html.parser')

# %%
title=[]
for i in article.find_all("a",class_="sc-5smygv-0 fIXTHm"):
    title.append(i.get_text())
    
aut=[]
for i in article.find_all("span",class_="sc-1w3fpd7-0 dnCnAO"):
    aut.append(i.get_text())

pub=[]
for i in article.find_all("span",class_="sc-1thf9ly-2 dvggWt"):
    pub.append(i.get_text())

df= pd.DataFrame({'Paper Title':title,'Author':aut,'Published Data':pub,'Paper-url':links})
df
# Out:
#                                           Paper Title  \
# 0                                    Reward is enough
# 1                           Making sense of raw input
# 2   Law and logic: A review from an argumentation ...
# 3              Creativity and artificial intelligence
# 4   Artificial cognition for social human–robot in...
# 5   Explanation in artificial intelligence: Insigh...
# 6                       Making sense of sensory input
# 7   Conflict-based search for optimal multi-agent ...
# 8   Between MDPs and semi-MDPs: A framework for te...
# 9   The Hanabi challenge: A new frontier for AI re...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11           Argumentation in artificial intelligence
# 12  Algorithms for computing strategies in two-pla...
# 13      Multiple object tracking: A literature review
# 14  Selection of relevant features and examples in...
# 15  A survey of inverse reinforcement learning: Ch...
# ...

# %% [markdown]
# 9) Write a python program to scrape mentioned details from dineout.co.in :
# i) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image URL

# %%
page10 = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
rest = BeautifulSoup(page10.content,'html.parser')

# %%
names =[]

for i in rest.find_all("div",class_="restnt-info cursor"):
    names.append(i.get_text())
    
cousine =[]
for i in rest.find_all("div",class_="detail-info"):
    cousine.append(i.get_text().split('|')[1])
    
loc =[]

for i in rest.find_all("div",class_="restnt-loc ellipsis"):
    loc.append(i.get_text())
    
rating = []

for i in rest.find_all("div",class_="restnt-rating rating-4"):
    rating.append(i.get_text())
    
img = []

for i in rest.find_all("img",class_="no-img"):
    img.append(i.get('data-src'))
df= pd.DataFrame({'Restaurant Names':names,'Cousine':cousine,'Location':loc,'Ratings':rating,'Images-url':img})
df
# Out:
#                                     Restaurant Names  \
# 0      Castle BarbequeConnaught Place, Central Delhi
# 1  Jungle Jamboree3CS Mall,Lajpat Nagar - 3, Sout...
# 2  Castle BarbequePacific Mall,Tagore Garden, Wes...
# 3  Cafe KnoshThe Leela Ambience Convention Hotel,...
# 4  The Barbeque CompanyGardens Galleria,Sector 38...
# 5    India GrillHilton Garden Inn,Saket, South Delhi
# 6  Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 7  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 8  Indian Grill RoomSuncity Business Tower,Golf C...
#
#                          Cousine  \
# 0          Chinese, North Indian
# 1   North Indian, Asian, Italian
# 2          Chinese, North Indian
# 3           Italian, Continental
# 4          North Indian, Chinese
# 5          North Indian, Italian
# 6                   North Indian
# 7                   North Indian
# 8          North Indian, Mughlai
#
#                                             Location Ratings  \
# ...

# %% [markdown]
# 10) Write a python program to scrape the details of top publications from Google Scholar from
# https://scholar.google.com/citations?view_op=top_venues&hl=en
# i) Rank
# ii) Publication
# iii) h5-index
#  iv) h5-median

# %%
import requests
import re
from bs4 import BeautifulSoup
from lxml import html
import pandas as pd

response = requests.get("https://scholar.google.com/citations?view_op=top_venues&hl=en") 
soup = BeautifulSoup(response.text,"lxml") 
# tr is for table rows from a webpage
rows = soup.findAll('tr')
list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2.replace('\n', ''))
    print(clean2)
# Out:
# []
# [1., Nature, 444, 667]
# [2., The New England Journal of Medicine, 432, 780]
# [3., Science, 401, 614]
# [4., IEEE/CVF Conference on Computer Vision and Pattern Recognition, 389, 627]
# [5., The Lancet, 354, 635]
# [6., Advanced Materials, 312, 418]
# [7., Nature Communications, 307, 428]
# [8., Cell, 300, 505]
# [9., International Conference on Learning Representations, 286, 533]
# [10., Neural Information Processing Systems, 278, 436]
# [11., JAMA, 267, 425]
# [12., Chemical Reviews, 265, 444]
# [13., Proceedings of the National Academy of Sciences, 256, 364]
# [14., Angewandte Chemie, 245, 332]
# [15., Chemical Society Reviews, 244, 386]
# [16., Journal of the American Chemical Society, 242, 344]
# [17., IEEE/CVF International Conference on Computer Vision, 239, 415]
# [18., Nucleic Acids Research, 238, 550]
# [19., International Conference on Machine Learning, 237, 421]
# [20., Nature Medicine, 235, 389]
# [21., Renewable and Sustainable Energy Reviews, 227, 324]
# ...

# %%
df = pd.DataFrame(list_rows)
df.head(10)
df1 = df[0].str.split(',', expand=True)
df1
# The data frame consists of unwanted square brackets. So, to remove them we have to use the following code
df1[0] = df1[0].str.strip('[')
df1[0] = df1[0].str.strip('.')
df1[3] = df1[3].str.strip(']')
df1.drop(df1.index[:1], inplace=True)
df1 = df1.reset_index().drop(['index'], axis = 1)
df1
# Out:
#       0                                                  1     2     3
# 0     1                                             Nature   444   667
# 1     2                The New England Journal of Medicine   432   780
# 2     3                                            Science   401   614
# 3     4   IEEE/CVF Conference on Computer Vision and Pa...   389   627
# 4     5                                         The Lancet   354   635
# ..  ...                                                ...   ...   ...
# 95   96                       Journal of Business Research   145   233
# 96   97                                   Molecular Cancer   145   209
# 97   98                                            Sensors   145   201
# 98   99                              Nature Climate Change   144   228
# 99  100                    IEEE Internet of Things Journal   144   212
#
# [100 rows x 4 columns]

# %%
# To get the table headers
col_labels = soup.find_all('th')
# for head in col_labels:
#     th.head.strip('\n\r\t": ')
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2.replace('\n', ' '))
print(all_header)
# Out:
# ['[, Publication, h5-index, h5-median]']

# %%
df2.head()
df3 = df2[0].str.split(',', expand=True)
df3[0] = df3[0].str.strip('[')
df3[3] = df3[3].str.strip(']')
df3[0] = "Rank"
df3
# Out:
#       0             1          2           3
# 0  Rank   Publication   h5-index   h5-median

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4 = df4.reset_index().drop(['index'], axis = 1)
df4 = df4.rename(columns=df3.iloc[0])
df4.drop(df4.index[:1], inplace=True)
df4 = df4.reset_index().drop(['index'], axis = 1)
df4
# Out:
#    Rank                                        Publication  h5-index  \
# 0     1                                             Nature       444
# 1     2                The New England Journal of Medicine       432
# 2     3                                            Science       401
# 3     4   IEEE/CVF Conference on Computer Vision and Pa...       389
# 4     5                                         The Lancet       354
# ..  ...                                                ...       ...
# 95   96                       Journal of Business Research       145
# 96   97                                   Molecular Cancer       145
# 97   98                                            Sensors       145
# 98   99                              Nature Climate Change       144
# 99  100                    IEEE Internet of Things Journal       144
#
#     h5-median
# 0         667
# 1         780
# 2         614
# 3         627
# 4         635
# ..        ...
# 95        233
# ...
